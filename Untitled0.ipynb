# %%
# Install system dependencies in Colab
system("apt-get install -y libgsl-dev libxml2-dev libcurl4-openssl-dev libssl-dev")

# %%
# Install revtools package with dependencies
# Github repo : https://github.com/mjwestgate/revtools

install.packages("revtools", repos = c("https://mjwestgate.r-universe.dev", "https://cloud.r-project.org"), dependencies = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘topicmodels’

# %%
library(revtools)
